# %% [markdown]
# # Kimi K3 architecture labs — toy scale
# Notebook này chạy các implementation giáo dục; **không phải** mã hoặc weights Kimi K3. Chạy từ repository root.

# %%
# Import pathlib để kiểm tra đúng working directory trước khi chạy lab.
from pathlib import Path

# Đường dẫn này phải tồn tại khi notebook được mở từ repository root.
LAB_DIR = Path('courses/kimi-k3-frontier-systems/code/python')
assert LAB_DIR.exists(), 'Hãy đổi working directory về repository root.'
sorted(path.name for path in LAB_DIR.glob('*.py'))

# %%
# runpy chạy script trong process notebook và vẫn giữ traceback dễ đọc.
import runpy

# Thực thi toy KDA; script tự kiểm tra shape và lower-bounded decay.
runpy.run_path(str(LAB_DIR / 'toy_kda.py'), run_name='__main__')

# %%
# Chạy lần lượt depth-mixing và routing labs để so các invariant.
runpy.run_path(str(LAB_DIR / 'toy_attnres.py'), run_name='__main__')
runpy.run_path(str(LAB_DIR / 'quantile_balancing.py'), run_name='__main__')

# %% [markdown]
# ## Bài tập
# 1. KDA: chạy chuỗi 32 token và theo dõi norm state.
# 2. AttnRes: tạo synthetic retrieval task và so residual sum.
# 3. QB: thử ba phân phối router score, báo load variance và assignment churn.
# 4. Trong report, ghi rõ kết quả nào chỉ đúng ở toy scale.
